# %%
from sage.plot.plot3d.shapes import *

# %%
u,v=var('u,v')
parametric_plot((,(u,0,pi/2),(v,0,pi/2))

# %%
f = (lambda u,v: cos(u)*cos(v), lambda u,v: cos(u)*sin(v), lambda u,v: sin(u))
p = parametric_plot3d(f, (0,2*pi/16), (0,pi/6),color="red")

# %%
Sphere(.9, color='yellow')+p
# Out:
# Graphics3d Object

# %%
N=20
a = []
for i in range(N):
    s = (i+1)/N
    a.append((0,log(tan(s/2+pi/4))))
#line([(0,log(tan(s/2+pi/4))) for s in sxrange(0.01,pi,0.05)])

# %%
l = []
du=pi/8
dv=pi/6
M = 5
for i in range(M):
    for j in range(M):
        l.append(point2d((du*i*pi/M,log(tan(dv*j*pi/M/2+pi/4))),size=50))
#a0 = point2d((0,0),size=50)
#a1 = point2d((0,log(tan(dv/2+pi/4))),size=50)
#a2 = point2d((du,0),size=50)
#a3 = point2d((du,log(tan(dv/2+pi/4))),size=50)
#a0+a1+a2+a3

# %%
sum(l)
# Out:
# Graphics object consisting of 25 graphics primitives

# %%
L = 20
l = []
dv = pi/16
for i in range(L):
    u = pi*(i+1)/L-pi
    l.append(point2d((u,log(tan(pi/4))),size=50))
    l.append(point2d((u,log(tan(dv/2+pi/40))),size=50))
sum(l)
# Out:
# Graphics object consisting of 40 graphics primitives

# %%
L = 20
l = []
dv = pi/16
for i in range(L):
    u = -du
    du = pi/8
    v = pi*(i+1)/L-pi
    l.append(point2d((cos(u)*sin(v),sin(v)),size=50))
    l.append(point2d((cos(u+du)*sin(v),sin(v)),size=50))
    #u = pi*(i+1)/L-pi
    #l.append(point2d((u,log(tan(pi/4))),size=50))
    #l.append(point2d((u,log(tan(dv/2+pi/40))),size=50))
sum(l)
# Out:
# Graphics object consisting of 40 graphics primitives
